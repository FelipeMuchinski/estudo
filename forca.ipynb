# %% [markdown]
# <a href="https://colab.research.google.com/github/FelipeMuchinski/estudo/blob/main/forca.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pytest

from forca import Boneco, PalavraSecreta, JogoDaForca

# 6.1 TESTES PARA A CLASSE BONECO

def test_boneco_inicia_no_estado_zero():
    boneco = Boneco(dificuldade="normal")
    assert boneco.estado == 0

def test_boneco_armazena_dificuldade_corretamente():
    boneco = Boneco(dificuldade="facil")
    assert boneco.dificuldade == "facil"

def test_boneco_dificuldade_invalida_gera_erro():
    with pytest.raises(ValueError):
        Boneco(dificuldade="super_dificil")

# 6.2 TESTES PARA A CLASSE PALAVRASECRETA


def test_palavra_convertida_para_maiuscula_e_sem_espacos():
    palavra_sec = PalavraSecreta("  python  ")
    assert palavra_sec.palavra == "PYTHON"

def test_palavra_com_numeros_gera_erro():
    with pytest.raises(ValueError):
        PalavraSecreta("python123")

def test_tentar_letra_correta_retorna_true():
    palavra_sec = PalavraSecreta("CASA")
    resultado = palavra_sec.tentar_letra("A")
    assert resultado is True

def test_exibir_progresso_com_letras_ocultas():
    palavra_sec = PalavraSecreta("CASA")
    palavra_sec.tentar_letra("A")
    assert palavra_sec.exibir_progresso() == "_ A _ A"

# 6.3 TESTES PARA A CLASSE JOGODAFORCA

def test_configurar_jogo_cria_objetos_corretamente():
    jogo = JogoDaForca()
    jogo.configurar_jogo(dificuldade="normal")
    assert isinstance(jogo.boneco, Boneco)
    assert isinstance(jogo.palavra_secreta, PalavraSecreta)

# %%
# !pytest test_forca.py
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.12.13, pytest-8.4.2, pluggy-1.6.0
# rootdir: /content
# plugins: langsmith-0.8.5, anyio-4.13.0, typeguard-4.5.2
# collected 0 items / 1 error
#
# ==================================== ERRORS ====================================
# ________________________ ERROR collecting test_forca.py ________________________
# /usr/local/lib/python3.12/dist-packages/_pytest/python.py:498: in importtestmodule
#     mod = import_path(
# /usr/local/lib/python3.12/dist-packages/_pytest/pathlib.py:587: in import_path
#     importlib.import_module(module_name)
# /usr/lib/python3.12/importlib/__init__.py:90: in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# <frozen importlib._bootstrap>:1387: in _gcd_import
#     ???
# <frozen importlib._bootstrap>:1360: in _find_and_load
#     ???
# ...

# %%
# %%writefile forca.py
import os
import random
from typing import List, Set

class Boneco:
    def __init__(self, dificuldade: str) -> None:
        pass
    @property
    def estado(self) -> int:
        pass
    @property
    def max_estado(self) -> int:
        pass
    @property
    def dificuldade(self) -> str:
        pass
    def avancar(self) -> None:
        pass
    def foi_completado(self) -> bool:
        pass
    def desenhar(self) -> str:
        pass

class PalavraSecreta:
    def __init__(self, palavra: str, revelar_primeira_letra: bool = False) -> None:
        pass
    @property
    def palavra(self) -> str:
        pass
    def tentar_letra(self, letra: str) -> bool:
        pass
    def exibir_progresso(self) -> str:
        pass
    def foi_descoberta(self) -> bool:
        pass

class JogoDaForca:
    def __init__(self) -> None:
        pass
    @staticmethod
    def limpar_tela() -> None:
        pass
    def selecionar_dificuldade(self) -> str:
        pass
    def configurar_jogo(self, dificuldade: str) -> None:
        pass
    def exibir_estado(self) -> None:
        pass
    def ler_letra(self) -> str:
        pass
    def processar_tentativa(self, letra: str) -> None:
        pass
    def jogar(self) -> None:
        pass

if __name__ == "__main__":
    jogo = JogoDaForca()
    jogo.jogar()
# Out:
# Overwriting forca.py

# %%
# %%writefile test_forca.py
import pytest
from forca import Boneco, PalavraSecreta, JogoDaForca

def test_boneco_inicia_no_estado_zero():
    boneco = Boneco(dificuldade="normal")
    assert boneco.estado == 0

def test_boneco_armazena_dificuldade_corretamente():
    boneco = Boneco(dificuldade="facil")
    assert boneco.dificuldade == "facil"

def test_palavra_convertida_para_maiuscula_e_sem_espacos():
    palavra_sec = PalavraSecreta("  python  ")
    assert palavra_sec.palavra == "PYTHON"

def test_tentar_letra_correta_retorna_true():
    palavra_sec = PalavraSecreta("CASA")
    resultado = palavra_sec.tentar_letra("A")
    assert resultado is True
# Out:
# Overwriting test_forca.py

# %%
# !pytest test_forca.py
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.12.13, pytest-8.4.2, pluggy-1.6.0
# rootdir: /content
# plugins: langsmith-0.8.5, anyio-4.13.0, typeguard-4.5.2
# collected 4 items
#
# test_forca.py FFFF                                                       [100%]
#
# =================================== FAILURES ===================================
# ______________________ test_boneco_inicia_no_estado_zero _______________________
#
#     def test_boneco_inicia_no_estado_zero():
#         boneco = Boneco(dificuldade="normal")
# >       assert boneco.estado == 0
# E       assert None == 0
# E        +  where None = <forca.Boneco object at 0x7ee1cc0be510>.estado
#
# test_forca.py:6: AssertionError
# ________________ test_boneco_armazena_dificuldade_corretamente _________________
#
#     def test_boneco_armazena_dificuldade_corretamente():
#         boneco = Boneco(dificuldade="facil")
# ...

# %%
# !pytest test_forca.py
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.12.13, pytest-8.4.2, pluggy-1.6.0
# rootdir: /content
# plugins: langsmith-0.8.5, anyio-4.13.0, typeguard-4.5.2
# collected 0 items / 1 error
#
# ==================================== ERRORS ====================================
# ________________________ ERROR collecting test_forca.py ________________________
# /usr/local/lib/python3.12/dist-packages/_pytest/python.py:498: in importtestmodule
#     mod = import_path(
# /usr/local/lib/python3.12/dist-packages/_pytest/pathlib.py:587: in import_path
#     importlib.import_module(module_name)
# /usr/lib/python3.12/importlib/__init__.py:90: in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# <frozen importlib._bootstrap>:1387: in _gcd_import
#     ???
# <frozen importlib._bootstrap>:1360: in _find_and_load
#     ???
# ...

# %%
import sys
if 'forca' in sys.modules:
    del sys.modules['forca']

# %%
# !pytest test_forca.py
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.12.13, pytest-8.4.2, pluggy-1.6.0
# rootdir: /content
# plugins: langsmith-0.8.5, anyio-4.13.0, typeguard-4.5.2
# collected 0 items
#
# ============================ no tests ran in 0.01s =============================
# ERROR: file or directory not found: test_forca.py

# %%
# %%writefile test_forca.py
import pytest
from forca import Boneco, PalavraSecreta, JogoDaForca

# TESTES PARA A CLASSE BONECO

def test_boneco_inicia_no_estado_zero():
    boneco = Boneco(dificuldade="normal")
    assert boneco.estado == 0

def test_boneco_armazena_dificuldade_corretamente():
    boneco = Boneco(dificuldade="facil")
    assert boneco.dificuldade == "facil"

def test_boneco_dificuldade_invalida_gera_erro():
    with pytest.raises(ValueError):
        Boneco(dificuldade="expert")



# TESTES PARA A CLASSE PALAVRASECRETA

def test_palavra_convertida_para_maiuscula_e_sem_espacos():
    palavra_sec = PalavraSecreta("  python  ")
    assert palavra_sec.palavra == "PYTHON"

def test_palavra_com_numeros_gera_erro():
    with pytest.raises(ValueError):
        PalavraSecreta("python123")

def test_tentar_letra_correta_retorna_true():
    palavra_sec = PalavraSecreta("CASA")
    resultado = palavra_sec.tentar_letra("A")
    assert resultado is True

def test_exibir_progresso_com_letras_ocultas():
    palavra_sec = PalavraSecreta("CASA")
    palavra_sec.tentar_letra("A")
    assert palavra_sec.exibir_progresso() == "_ A _ A"



# TESTES PARA A CLASSE JOGODAFORCA


def test_configurar_jogo_cria_objetos_corretamente():
    jogo = JogoDaForca()
    jogo.configurar_jogo(dificuldade="normal")
    assert isinstance(jogo.boneco, Boneco)
    assert isinstance(jogo.palavra_secreta, PalavraSecreta)
# Out:
# Overwriting test_forca.py

# %%
# !pytest test_forca.py
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.12.13, pytest-8.4.2, pluggy-1.6.0
# rootdir: /content
# plugins: langsmith-0.8.5, anyio-4.13.0, typeguard-4.5.2
# collected 8 items
#
# test_forca.py ........                                                   [100%]
#
# ============================== 8 passed in 0.02s ===============================

# %%
# !python forca.py

# %%
from forca import JogoDaForca


jogo = JogoDaForca()
jogo.jogar()
# Out:
# Escolha a dificuldade (1-Facil, 2-Normal, 3-Dificil): 2
# ================ JOGO DA FORCA ================
# Dificuldade: NORMAL
# ______
# |    |
# |
# |
# |
#
# Progresso: _ _ _ _ _ _ _ _
# Letras tentadas:
# Erros cometidos: 0 / 6
# Mensagem: Bem-vindo ao jogo da forca!
# ...
# Digite uma letra: a
# ================ JOGO DA FORCA ================
# Dificuldade: NORMAL
# ______
# |    |
# |
# |
# |
#
# Progresso: _ _ _ _ _ A _ _
# Letras tentadas: A
# Erros cometidos: 0 / 6
# Mensagem: Boa! A letra 'A' está na palavra.
# ...
# Digite uma letra: e
# ================ JOGO DA FORCA ================
# Dificuldade: NORMAL
# ______
# |    |
# |
# |
# |
#
# Progresso: _ _ _ _ _ A _ E
# Letras tentadas: A, E
# Erros cometidos: 0 / 6
# Mensagem: Boa! A letra 'E' está na palavra.
# ...
# Digite uma letra: o
# ================ JOGO DA FORCA ================
# Dificuldade: NORMAL
# ______
# |    |
# |
# |
# |
#
# Progresso: _ O _ _ _ A _ E
# Letras tentadas: A, E, O
# Erros cometidos: 0 / 6
# ...
